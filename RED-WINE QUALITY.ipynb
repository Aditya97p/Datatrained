# %%
import pandas as pd
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib  import * 
from scipy import stats
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv("DataTrained/winequality-red.csv")

# %%
df_train.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df_train.shape
# Out:
# (1599, 12)

# %%
# checking for null values

df_train.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
j=1 
fig = plt.figure(figsize = (15,15))
for i in df_train.columns:
    plt.subplot(4,3,j)
    sns.distplot(df_train[i])
    j=j+1

# %%
df_train.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# let's check for unique quality scores.

df_train['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
#comparing the count of different quality scores.

sns.countplot(x='quality',data=df_train)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
plt.figure(figsize=(15,16))

plt.subplot(4, 3, 1)
sns.scatterplot(x='quality',y="citric acid",data=df_train)

plt.subplot(4, 3, 2)
sns.scatterplot(x='quality',y="fixed acidity",data=df_train)

plt.subplot(4, 3, 3)
sns.scatterplot(x='quality',y="volatile acidity",data=df_train)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
plt.figure(figsize=(15,16))

plt.subplot(4, 3, 1)
sns.scatterplot(x='quality',y="pH",data=df_train)

plt.subplot(4, 3, 2)
sns.scatterplot(x='quality',y="chlorides",data=df_train)

plt.subplot(4, 3, 3)
sns.scatterplot(x='quality',y="density",data=df_train)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='density'>

# %%
plt.figure(figsize=(15,16))

plt.subplot(4, 3, 1)
sns.scatterplot(x='quality',y="free sulfur dioxide",data=df_train)

plt.subplot(4, 3, 2)
sns.scatterplot(x='quality',y="total sulfur dioxide",data=df_train)

plt.subplot(4, 3, 3)
sns.scatterplot(x='quality',y="alcohol",data=df_train)

plt.subplot(4, 3, 4)
sns.scatterplot(x='quality',y="sulphates",data=df_train)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %%
# Plotting Correlation graph

correlation=df_train.corr()
plt.figure(figsize=(14,8))
sns.heatmap(correlation,annot=True,linewidth=0,vmin=-1,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Alcohol is having influence on quality of wine.
# ### Alcohol and density have a negative correlation(-0.49)
# ### pH,free sulfure dioxide ,chlorides ,residual sugar do not have high correlation on quality

# %%
correlation['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64

# %% [markdown]
# #### It seems like alcohol is the most correlated variable with wine quality .

# %%
plt.figure(figsize=(16,16))

plt.subplot(4, 3, 1)
sns.boxplot(x="quality",y="alcohol",data=df_train)

plt.subplot(4, 3, 2)
sns.boxplot(x="quality",y="sulphates",data=df_train)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %%
plt.figure(figsize=(16,16))

plt.subplot(4, 3, 1)
sns.boxplot(x="quality",y="citric acid",data=df_train)

plt.subplot(4, 3, 2)
sns.boxplot(x="quality",y="volatile acidity",data=df_train)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
plt.figure(figsize =(15,5))
sns.distplot(df_train[df_train['quality'] == 8]['alcohol'],hist=False ,color ='red')
sns.distplot(df_train[df_train['quality'] == 7]['alcohol'],hist=False,color ='green')
sns.distplot(df_train[df_train['quality'] == 6]['alcohol'],hist=False,color ='aqua')
sns.distplot(df_train[df_train['quality'] == 5]['alcohol'],hist=False,color = 'blue')
sns.distplot(df_train[df_train['quality'] == 4]['alcohol'],hist=False,color ='coral')
sns.distplot(df_train[df_train['quality'] == 3]['alcohol'],hist=False,color ='yellow')
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# ### The top quality wine(7 and 8) will have have higher alcohol content.
# ### The inferior quality of wine usually has <10% alcohol.

# %% [markdown]
# # Marking quality more than 7  as good and less than equal to 7 as not good

# %%
df_train['quality'] = df_train.quality.apply(lambda x : 'not good' if x < 7 else 'good')

# %%
df_train.tail(50)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1549            7.4             0.360         0.30             1.8      0.074
# 1550            7.1             0.680         0.00             2.3      0.087
# 1551            7.1             0.670         0.00             2.3      0.083
# 1552            6.3             0.680         0.01             3.7      0.103
# 1553            7.3             0.735         0.00             2.2      0.080
# 1554            6.6             0.855         0.02             2.4      0.062
# 1555            7.0             0.560         0.17             1.7      0.065
# 1556            6.6             0.880         0.04             2.2      0.066
# 1557            6.6             0.855         0.02             2.4      0.062
# 1558            6.9             0.630         0.33             6.7      0.235
# 1559            7.8             0.600         0.26             2.0      0.080
# ...

# %% [markdown]
# # converting good as 0 and not good as 1 numerical values

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df_train['quality'] = le.fit_transform(df_train['quality'])
df_train['quality'].unique()
# Out:
# array([1, 0])

# %%
df_train['quality'].value_counts().plot(kind = 'pie',autopct ='%.2f')
# Out:
# <AxesSubplot:ylabel='quality'>

# %%
plt.figure(figsize=(16,16))

plt.subplot(4, 3, 1)
sns.boxplot(x="quality",y="sulphates",data=df_train)

plt.subplot(4, 3, 2)
sns.boxplot(x="quality",y="alcohol",data=df_train)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
plt.figure(figsize=(16,16))

plt.subplot(4, 3, 1)
sns.boxplot(x="quality",y="citric acid",data=df_train)

plt.subplot(4, 3, 2)
sns.boxplot(x="quality",y="volatile acidity",data=df_train)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %% [markdown]
# ## removing target feature

# %%
target = df_train['quality']

# %%
df_train=df_train.drop('quality', axis=1)

# %% [markdown]
# #  Train and Spliting the data

# %%
X = df_train
y = target

# %%
from sklearn.model_selection import train_test_split
x_train, x_pred, y_train, y_pred = train_test_split(X,y, test_size=0.2)

# %%
print('X_train shape', x_train.shape)
print('y_train shape', y_train.shape)
print('X_pred shape', x_pred.shape)
print('y_pred shape', y_pred.shape)
# Out:
# X_train shape (1279, 11)
# y_train shape (1279,)
# X_pred shape (320, 11)
# y_pred shape (320,)

# %% [markdown]
# #  Applying models

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # RandomForestClassifier

# %%
rf_clf = RandomForestClassifier()
rf_clf.fit(x_train,y_train)
pred = rf_clf.predict(x_pred)

# %% [markdown]
# # checking which all features are important for wine quality.

# %%
for name, score in zip(X.columns, rf_clf.feature_importances_):
    print(name, score *100)
# Out:
# fixed acidity 7.723856175209552
# volatile acidity 11.145110133212865
# citric acid 9.153241163047618
# residual sugar 6.700403317725493
# chlorides 7.335488984542629
# free sulfur dioxide 6.444919828716425
# total sulfur dioxide 7.4343535620834285
# density 9.49656481605778
# pH 6.394766059012177
# sulphates 11.325996630112424
# alcohol 16.84529933027961

# %%
data = {'Features': X.columns , '%Importance': rf_clf.feature_importances_ * 100 }
temp = pd.DataFrame(data)

plt.figure(figsize =(20,5))
sns.barplot(data =temp.sort_values(by =['%Importance']) ,x='Features', y ='%Importance')
# Out:
# <AxesSubplot:xlabel='Features', ylabel='%Importance'>

# %% [markdown]
# ### Alcohol is the most important feature
#
# ### sulphates are the second most important feature

# %% [markdown]
# # Feature Scaling

# %%
# Applying StandardScaler before fitting ML model to normalize the features

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit_transform(x_train)
sc.transform(x_pred)
# Out:
# array([[-0.18668202, -0.82208867, -1.08508398, ...,  0.37724029,
#         -0.81070207, -0.49588782],
#        [ 0.33037686, -0.70929317,  0.23922265, ...,  0.44210858,
#          0.63552638,  0.07131275],
#        [-0.99099583,  1.85680435, -1.28882347, ...,  1.48000121,
#         -0.34790897,  0.54397989],
#        ...,
#        [-0.87609386,  0.24946854, -1.39069321, ...,  0.76645003,
#         -0.57930552,  0.73304675],
#        [ 0.44527884, -1.78085038,  0.493897  , ..., -0.53091576,
#         -0.46360724,  0.63851332],
#        [ 0.90488673, -0.99128191,  0.69763648, ..., -0.66065234,
#         -0.92640035, -0.87402154]])

# %%
from xgboost import XGBClassifier

log_clf = LogisticRegression()
dt_clf = DecisionTreeClassifier()
svm_clf = SVC(probability =True)
knn_clf = KNeighborsClassifier()
ada_clf = AdaBoostClassifier()
xgb_clf= XGBClassifier()
rf_clf = RandomForestClassifier()

voting_clf = VotingClassifier(
 estimators=[('lr', log_clf), ('rf', rf_clf), ('svc', svm_clf), ('knn',knn_clf),('dt',dt_clf)],
 voting='hard',n_jobs = -1)


voting_clf.fit(x_train, y_train)
for clf in (log_clf, rf_clf, svm_clf,knn_clf,dt_clf,voting_clf):
    clf.fit(x_train, y_train)
    pred = clf.predict(x_pred)
    print(clf.__class__.__name__, accuracy_score(y_pred, pred) * 100)
# Out:
# LogisticRegression 89.0625
# RandomForestClassifier 94.375
# SVC 86.875
# KNeighborsClassifier 85.9375
# DecisionTreeClassifier 86.5625
# VotingClassifier 90.0

# %% [markdown]
# ## finding the best hyperparameter using GRID Search CV

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
para_knn = {'n_neighbors':np.arange(1, 50)}
grid_knn = GridSearchCV(knn_clf, param_grid=para_knn, cv=5)
para_dt = {'criterion':['gini','entropy'],'max_depth':np.arange(1, 50), 'min_samples_leaf':[1,2,4,5,10,20,30,40,80,100]}
grid_dt = GridSearchCV(dt_clf, param_grid=para_dt, cv=5)
param_rf = {'n_estimators':[100,200, 350, 500], 'min_samples_leaf':[2, 10, 30]}
grid_rf = GridSearchCV(rf_clf, param_grid=param_rf, cv=5)
param_log = {'penalty':['l2','l1'] }
grid_log = GridSearchCV(log_clf,param_grid= param_log , cv=5)

params_ada = {'n_estimators': [50,100,250,400,500,600], 'learning_rate': [0.2,0.5,0.8,1]}
grid_ada =  GridSearchCV(ada_clf, param_grid=params_ada, cv=5)


params_xgb = {'n_estimators': [50,100,250,400,600,800,1000], 'learning_rate': [0.2,0.5,0.8,1]}
grid_xgb =  RandomizedSearchCV(xgb_clf, param_distributions=params_xgb, cv=5)

# %%
grid_knn.fit(x_train, y_train)
grid_dt.fit(x_train, y_train)
grid_rf.fit(x_train, y_train)
grid_ada.fit(x_train, y_train)
grid_xgb.fit(x_train, y_train)


classifiers = ['grid_log','grid_knn','grid_dt','grid_rf','grid_ada','grid_xgb']


print("parameters for KNN:", grid_knn.best_params_)
print("parameters for Decision Tree:", grid_dt.best_params_)
print("parameters for Random Forest:", grid_rf.best_params_)
print("parameters for AdaBoost:", grid_ada.best_params_)
print("parameters for XGBoost:", grid_xgb.best_params_)
# Out:
# parameters for KNN: {'n_neighbors': 27}
# parameters for Decision Tree: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 20}
# parameters for Random Forest: {'min_samples_leaf': 2, 'n_estimators': 100}
# parameters for AdaBoost: {'learning_rate': 1, 'n_estimators': 250}
# parameters for XGBoost: {'n_estimators': 1000, 'learning_rate': 0.5}

# %% [markdown]
# ## Applying the best parameters on our classifier models.

# %%
knn = KNeighborsClassifier(n_neighbors= 27)
dt = DecisionTreeClassifier(criterion= 'gini', max_depth= 5, min_samples_leaf= 20)
rf = RandomForestClassifier(min_samples_leaf= 2, n_estimators = 100)
ada =AdaBoostClassifier(learning_rate= 1, n_estimators= 250)
xgb = XGBClassifier(n_estimators= 1000, learning_rate= 0.5)

# %%
for clf in (knn, dt, rf, ada,xgb):
     clf.fit(x_train, y_train)
     pred_clf = clf.predict(x_pred)
     print(clf.__class__.__name__, accuracy_score(y_pred, pred_clf))
# Out:
# KNeighborsClassifier 0.875
# DecisionTreeClassifier 0.884375
# RandomForestClassifier 0.928125
# AdaBoostClassifier 0.89375
# XGBClassifier 0.9375

# %%
voting_clf = VotingClassifier(
 estimators=[ ('rf', rf), ('knn',knn),('dt',dt),('ada',ada),('xgb',xgb)],
 voting='hard',n_jobs = -1)

# %%
from sklearn.model_selection import cross_val_score
value = []
models = ['KNeighborsClassifier ','DecisionTreeClassifier','RandomForestClassifier ','AdaBoostClassifier ','XGBClassifier ','Voting Classifier']

for i in [knn, dt, rf, ada,xgb,voting_clf]:
    eval = cross_val_score(estimator = i, X = x_pred, y = y_pred, cv = 10)
    value.append(eval.mean())
    
data = {'Models': models , 'CrossValScore':  value  }
table = pd.DataFrame(data)

# %%
table
# Out:
#                     Models  CrossValScore
# 0    KNeighborsClassifier        0.865625
# 1   DecisionTreeClassifier       0.884375
# 2  RandomForestClassifier        0.859375
# 3      AdaBoostClassifier        0.850000
# 4           XGBClassifier        0.859375
# 5        Voting Classifier       0.881250

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data = table.sort_values(by='CrossValScore') ,y = 'Models', x= 'CrossValScore')
# Out:
# <AxesSubplot:xlabel='CrossValScore', ylabel='Models'>

# %% [markdown]
# # We can see that almost all the Models perform similarly after cross validation.
